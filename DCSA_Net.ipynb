# %% [markdown]
# # Import Necessary Library

# %%
from tensorflow import keras
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.utils import plot_model
# from keras.utils.vis_utils import plot_model

# %% [markdown]
# # Model Parameters

# %%
input_shape = 128, 128, 3
batch_sizes = 8
epoch = 100

# %% [markdown]
# # Function for Stain Normalization

# %%
def Stain_Normalization(img, saveFile=None, Io=255, alpha=1, beta=0.15):

    HERef = np.array([[0.587, 0.136],
                     [0.754, 0.833],
                     [0.294, 0.536]])


    maxCRef = np.array([1.9705, 1.0308])

    # define height and width of image
    
    h, w, c = img.shape

    # reshape image
    img = img.reshape((-1, 3))
    
    # calculate optical density
    OD = -np.log((img.astype(np.float) + 1) / Io)

    # rows correspond to channels (RGB), columns to OD values
    Y = np.reshape(OD, (-1, 3))
    
    # remove transparent pixels
    ODhat = OD[~np.any(OD < beta, axis=1)]

    # compute eigenvectors
    eigvals, eigvecs = np.linalg.eigh(np.cov(ODhat.T))

    # eigvecs *= -1

    # project on the plane spanned by the eigenvectors corresponding to the two
    # largest eigenvalues
    That = ODhat.dot(eigvecs[:, 1:3])

    phi = np.arctan2(That[:, 1], That[:, 0])

    minPhi = np.percentile(phi, alpha)
    maxPhi = np.percentile(phi, 100 - alpha)

    vMin = eigvecs[:, 1:3].dot(np.array([(np.cos(minPhi), np.sin(minPhi))]).T)
    vMax = eigvecs[:, 1:3].dot(np.array([(np.cos(maxPhi), np.sin(maxPhi))]).T)

    # a heuristic to make the vector corresponding to hematoxylin first and the
    # one corresponding to eosin second
    if vMin[0] > vMax[0]:
        HE = np.array((vMin[:, 0], vMax[:, 0])).T
    else:
        HE = np.array((vMax[:, 0], vMin[:, 0])).T

    # determine concentrations of the individual stains
    C = np.linalg.lstsq(HE, Y.T, rcond=None)[0]

    # normalize stain concentrations
    maxC = np.array([np.percentile(C[0, :], 99), np.percentile(C[1, :], 99)])
    tmp = np.divide(maxC, maxCRef)
    C2 = np.divide(C, tmp[:, np.newaxis])

    # recreate the image using reference mixing matrix
    Inorm = np.multiply(Io, np.exp(-HERef.dot(C2)))
    Inorm[Inorm > 255] = 254
    Inorm = np.reshape(Inorm.T, (h, w, 3)).astype(np.uint8)

    return Inorm

# %% [markdown]
# # Function for DCSAM 1

# %%
def spatial_conv1(x, kernel, filter_number, dilation):

    dense = keras.layers.Dense(filter_number, activation="relu")(x)
    
    conv1 = keras.layers.Conv2D(filter_number, (kernel, kernel), dilation_rate=dilation, padding='same')(x)
    conv1 = keras.layers.BatchNormalization(axis=3)(conv1)
    conv1 = keras.layers.Activation('relu')(conv1)
    
    squeeze = keras.layers.Conv2D(filter_number//8, (1, 1), padding='same', dilation_rate=1)(x)
    squeeze = keras.layers.BatchNormalization(axis=3)(squeeze)
    squeeze = keras.layers.Activation('relu')(squeeze)
    
    conv2 = keras.layers.Conv2D(filter_number, (kernel, kernel), dilation_rate=dilation, padding='same')(conv1)
    conv2 = keras.layers.BatchNormalization(axis=3)(conv2)
    conv2 = keras.layers.Activation('relu')(conv2)
    
    concat = keras.layers.concatenate([x, conv1, conv2, squeeze])
    
    activate = keras.layers.Dense(filter_number, use_bias=False, activation="sigmoid")(concat)

    return activate*dense

# %% [markdown]
# # Fuction for DCSAM 2

# %%
def spatial_conv2(x, kernel, filter_number, dilation):
    
    dense = keras.layers.Dense(filter_number, activation="relu")(x)
    
    conv1 = keras.layers.Conv2D(filter_number, (kernel, kernel), dilation_rate=dilation, padding='same')(x)
    conv1 = keras.layers.BatchNormalization(axis=3)(conv1)
    conv1 = keras.layers.Activation('relu')(conv1)
    
    conv2 = keras.layers.Conv2D(filter_number, (kernel, kernel), dilation_rate=dilation, padding='same')(conv1)
    conv2 = keras.layers.BatchNormalization(axis=3)(conv2)
    conv2 = keras.layers.Activation('relu')(conv2)
    
    squeeze = keras.layers.Conv2D(filter_number//8, (1, 1), padding='same', dilation_rate=1)(x)
    squeeze = keras.layers.BatchNormalization(axis=3)(squeeze)
    squeeze = keras.layers.Activation('relu')(squeeze)
    
    conv3 = keras.layers.Conv2D(filter_number, (kernel, kernel), dilation_rate=dilation, padding='same')(conv2)
    conv3 = keras.layers.BatchNormalization(axis=3)(conv3)
    conv3 = keras.layers.Activation('relu')(conv3)
    
    concat = keras.layers.concatenate([x, conv1, conv2, conv3, squeeze])
    
    activate = keras.layers.Dense(filter_number, use_bias=False, activation="sigmoid")(concat)
    
    return activate*dense

# %% [markdown]
# # Function for Encoder Block 1

# %%
def encoder_block1(input, kernel, filter_number, dilation):
    x = spatial_conv1(input, kernel, filter_number, dilation)
    p = keras.layers.MaxPooling2D((2,2), strides=(2, 2))(x)
    p = keras.layers.Dropout(0.3)(p)
    
    return x, p

# %% [markdown]
# # Function for Encoder Block 2

# %%
def encoder_block2(input, kernel, filter_number, dilation):
    x = spatial_conv2(input, kernel, filter_number, dilation)
    p = keras.layers.MaxPooling2D((2,2), strides=(2, 2))(x)
    p = keras.layers.Dropout(0.3)(p)
    
    return x, p

# %% [markdown]
# # Function for Decoder Block 1

# %%
def decoder_block_segment1(input, kernel, skip_features, filter_number, dilation):
    
    x = keras.layers.UpSampling2D(size=(2, 2), data_format="channels_last")(input)
    x = keras.layers.concatenate([x, skip_features])
    x = spatial_conv1(x, kernel, filter_number, dilation)
    
    return x

# %% [markdown]
# # Function for Decoder Block 2

# %%
def decoder_block_segment2(input, kernel, skip_features, filter_number, dilation):
    
    x = keras.layers.UpSampling2D(size=(2, 2), data_format="channels_last")(input)
    x = keras.layers.concatenate([x, skip_features])
    x = spatial_conv2(x, kernel, filter_number, dilation)
    
    return x

# %% [markdown]
# # Function for DCSA_Net

# %%
def DCSA_Net(input_shape):
    
    inputs = keras.Input(input_shape)

    conv1 = keras.layers.Conv2D(64, 5, strides=1, dilation_rate=1, padding='same')(inputs)
    conv1 = keras.layers.BatchNormalization(axis=3)(conv1)
    conv1 = keras.layers.Activation("relu")(conv1)
    conv2 = keras.layers.Conv2D(64, 3, strides=1, dilation_rate=1, padding='same')(inputs)
    conv2 = keras.layers.BatchNormalization(axis=3)(conv2)
    conv2 = keras.layers.Activation("relu")(conv2)
    s1 = keras.layers.concatenate([conv1, conv2])
    p1 = keras.layers.MaxPooling2D((2,2), strides=(2, 2))(s1)
    
    s2, p2 = encoder_block1(p1, 3, 128, 1)
    s3, p3 = encoder_block1(p2, 3, 256, 2)
    s4, p4 = encoder_block2(p3, 3, 512, 3)
    
    bridge = keras.layers.Conv2D(512, 1, strides=1, dilation_rate=1, padding='same')(p4)
    bridge = keras.layers.BatchNormalization()(bridge)
    bridge = keras.layers.Activation("relu")(bridge) #Bridge
    
    d1 = decoder_block_segment1(bridge, 3, s4, 512, 1)
    d2 = decoder_block_segment1(d1, 3, s3, 256, 1)
    d3 = decoder_block_segment2(d2, 3, s2, 128, 1)
    
    d4 = keras.layers.UpSampling2D(size=(2, 2), data_format="channels_last")(d3)
    d4 = keras.layers.concatenate([d4, s1])
    
    conv3 = keras.layers.Conv2D(64, 5, strides=1, dilation_rate=1, padding='same')(d4)
    conv3 = keras.layers.BatchNormalization(axis=3)(conv3)
    conv3 = keras.layers.Activation("relu")(conv3)
    conv4 = keras.layers.Conv2D(64, 3, strides=1, dilation_rate=1, padding='same')(d4)
    conv4 = keras.layers.BatchNormalization(axis=3)(conv4)
    conv4 = keras.layers.Activation("relu")(conv4)
    
    concat = keras.layers.concatenate([conv3, conv4])
    
    cnn_feature_vector = keras.layers.GlobalMaxPooling2D()(concat)
    attention_weights = keras.layers.Dense(units=128, activation='sigmoid')(cnn_feature_vector)
    attention_weights = keras.layers.Reshape((1,1,128))(attention_weights)
    weighted_image_output = keras.layers.Multiply()([concat, attention_weights])
    merged_image = keras.layers.concatenate([inputs, weighted_image_output])
    merged_image = keras.layers.Conv2D(3, (3, 3), padding='same', activation='relu')(merged_image)
    
    outputs = keras.layers.Conv2D(1, (1,1), padding='same', activation='sigmoid')(merged_image)
    
    model = keras.Model(inputs, outputs, name="DCSA_Net")
    
    return model

# %%
DCSA_model = DCSA_Net(input_shape)

DCSA_model.summary()
# Out:
# Model: "DCSA_Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 128, 128, 64) 4864        input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 128, 128, 64) 1792        input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 128, 128, 64) 256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 128, 128, 64) 256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 128, 128, 64) 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 128, 128, 64) 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 128, 128, 128 0           activation_27[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 128)  0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 128)  147584      max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 64, 64, 128)  512         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 128)  147584      activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 16)   2064        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 64, 128)  512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 64, 16)   64          conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 64, 64, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 64, 64, 16)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 64, 64, 400)  0           max_pooling2d_5[0][0]
#                                                                  activation_29[0][0]
#                                                                  activation_31[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 64, 64, 128)  51200       concatenate_15[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 64, 64, 128)  16512       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_6 (TFOpLambda) (None, 64, 64, 128)  0           dense_14[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 128)  0           tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 128)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 256)  295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 256)  1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 256)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 32)   4128        dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 256)  1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 32)   128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 256)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 32)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 32, 32, 672)  0           dropout_3[0][0]
#                                                                  activation_32[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 32, 32, 256)  172032      concatenate_16[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 32, 32, 256)  33024       dropout_3[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_7 (TFOpLambda) (None, 32, 32, 256)  0           dense_16[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 256)  0           tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 256)  0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 16, 16, 512)  1180160     dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 512)  2048        conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 512)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 16, 16, 512)  2359808     activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 512)  2048        conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 512)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 16, 16, 512)  2359808     activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 16, 16, 64)   16448       dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 16, 16, 512)  2048        conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 16, 16, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 512)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 64)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 16, 16, 1856) 0           dropout_4[0][0]
#                                                                  activation_35[0][0]
#                                                                  activation_36[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 16, 16, 512)  950272      concatenate_17[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 16, 16, 512)  131584      dropout_4[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_8 (TFOpLambda) (None, 16, 16, 512)  0           dense_18[0][0]
#                                                                  dense_17[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 512)    0           tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 512)    0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 512)    262656      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 512)    2048        conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 512)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 16, 16, 512)  0           activation_39[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 16, 16, 1024) 0           up_sampling2d_4[0][0]
#                                                                  tf.math.multiply_8[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 512)  4719104     concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 16, 16, 512)  2048        conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 16, 512)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 512)  2359808     activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 64)   65600       concatenate_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 16, 16, 512)  2048        conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 16, 16, 64)   256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 16, 16, 512)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 16, 16, 64)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 16, 16, 2112) 0           concatenate_18[0][0]
#                                                                  activation_40[0][0]
#                                                                  activation_42[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 16, 16, 512)  1081344     concatenate_19[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 16, 16, 512)  524800      concatenate_18[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_9 (TFOpLambda) (None, 16, 16, 512)  0           dense_20[0][0]
#                                                                  dense_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 512)  0           tf.math.multiply_9[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 32, 32, 768)  0           up_sampling2d_5[0][0]
#                                                                  tf.math.multiply_7[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 256)  1769728     concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 32, 32, 256)  1024        conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 32, 32, 256)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 256)  590080      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 32)   24608       concatenate_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 32, 32, 256)  1024        conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 32, 32, 32)   128         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 32, 32, 256)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 32, 32, 32)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 32, 32, 1312) 0           concatenate_20[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_44[0][0]
# __________________________________________________________________________________________________
# dense_22 (Dense)                (None, 32, 32, 256)  335872      concatenate_21[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 32, 32, 256)  196864      concatenate_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_10 (TFOpLambda (None, 32, 32, 256)  0           dense_22[0][0]
#                                                                  dense_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 256)  0           tf.math.multiply_10[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 64, 64, 384)  0           up_sampling2d_6[0][0]
#                                                                  tf.math.multiply_6[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 64, 64, 128)  442496      concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 64, 64, 128)  512         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 64, 64, 128)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 64, 64, 128)  147584      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 64, 64, 128)  512         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 64, 64, 128)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 64, 64, 128)  147584      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 64, 64, 16)   6160        concatenate_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 64, 64, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 64, 64, 16)   64          conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 64, 64, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 64, 64, 16)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 64, 64, 784)  0           concatenate_22[0][0]
#                                                                  activation_46[0][0]
#                                                                  activation_47[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_48[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 64, 64, 128)  100352      concatenate_23[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 64, 64, 128)  49280       concatenate_22[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 64, 64, 128)  0           dense_24[0][0]
#                                                                  dense_23[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 128 0           tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 128, 128, 256 0           up_sampling2d_7[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 128, 128, 64) 409664      concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 128, 128, 64) 147520      concatenate_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 128, 128, 64) 256         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 128, 128, 64) 256         conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 128, 128, 64) 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 128, 128, 64) 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 128, 128, 128 0           activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# global_max_pooling2d_1 (GlobalM (None, 128)          0           concatenate_25[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 128)          16512       global_max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 1, 128)    0           dense_25[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 128, 128, 128 0           concatenate_25[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 128, 128, 131 0           input_3[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 128, 128, 3)  3540        concatenate_26[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 128, 128, 1)  4           conv2d_54[0][0]
# ==================================================================================================
# Total params: 21,886,136
# Trainable params: 21,875,704
# Non-trainable params: 10,432
# __________________________________________________________________________________________________

# %%
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)

# %%
def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %%
def jacard_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# %%
def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)

# %%
callback = [keras.callbacks.ReduceLROnPlateau(factor=0.1, patience=5, cooldown=5, verbose=1),
            ModelCheckpoint('weight.h5', verbose=1, save_best_only=True, save_weights_only=True)]

# %%
DCSA_model.compile(optimizer="Adam", loss=['binary_crossentropy', dice_coef_loss, jacard_coef_loss], metrics=['accuracy', dice_coef, jacard_coef])

# %%
results = DCSA_model.fit(X_train, y_train, batch_size=batch_sizes, epochs=epoch, validation_data=(X_test, y_test), callbacks=callback, shuffle=True)

# %% [markdown]
# # Model Testing

# %%
y_pred = DCSA_Net.predict(image_dataset_Test)
y_pred_thresholded = y_pred > 0.5

gt_flat = mask_dataset_Test.flatten()
pred_flat = y_pred_thresholded.flatten()

accuracy = accuracy_score(gt_flat, pred_flat)

intersection = np.logical_and(mask_dataset_Test, y_pred_thresholded)
union = np.logical_or(mask_dataset_Test, y_pred_thresholded)

DiceCoef = 2. * intersection.sum() / (mask_dataset_Test.sum() + y_pred_thresholded.sum())

iou_score = np.sum(intersection) / np.sum(union)

print("Accuracy score is: ", accuracy)
print("Dice score is: ", DiceCoef)
print("IoU score is: ", iou_score)

# %% [markdown]
# # Test Single Image, Patching 512x512 to 128x128

# %%
from patchify import patchify, unpatchify
import cv2

image = cv2.imread("Image.bmp") ## size 512

# convert to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

normalize_image = Stain_Normalization(image)

r, g, b = cv2.split(normalize_image)

R_patches = patchify(r, (128, 128), step=64)
G_patches = patchify(g, (128, 128), step=64)
B_patches = patchify(b, (128, 128), step=64)

rgb = cv2.merge((R_patches,G_patches,B_patches))

rgb = rgb/255.

# %% [markdown]
# # Prediction and Merging from 128x128 to 512x512

# %%
def cell_segmentation(array):

    predict = []

    for i in range(array.shape[0]):
        for j in range(array.shape[1]):
        
            single_patch = array[i,j,:,:]

#             label, prob = model_StarDist.predict_instances(normalize(single_patch))
            expand_dim = np.expand_dims(single_patch, 0)
        
            prediction = (model.predict(expand_dim)[0,:,:,0] > 0.5).astype(np.uint8)
            
            predict.append(prediction)
    
    predict_array = np.array(predict)
    predict_array_reshaped = np.reshape(predict_array, (R_patches.shape[0], R_patches.shape[0], 128, 128))
    reconstructed_image = unpatchify(predict_array_reshaped, r.shape)
    binary = np.squeeze(reconstructed_image*255).astype('uint8')
    prediction_processing = post_processing(binary)
    
    return prediction_processing

# %% [markdown]
# # Function for Post-processing

# %%
from scipy import ndimage

def post_processing(binary):
    
    four_connectivity = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(5,5))
    opening = cv2.morphologyEx(binary, cv2.MORPH_OPEN, four_connectivity, iterations=1)
    fill = ndimage.binary_fill_holes(opening).astype('uint8')

    label_nuclei, n_output, n_stats, n_centroids = cv2.connectedComponentsWithStats(fill, connectivity=8)

    label_nuclei = label_nuclei - 1

    n_sizes = n_stats[1:, -1]

    window = np.zeros((binary.shape))
    
    for i in range(0, label_nuclei):
    
        if n_sizes[i] >= 20:
            window[n_output == i + 1] = 255

    noise_remove = (window).astype(np.uint8)
    
    return noise_remove

# %%
Nuclei_Segmentation = cell_segmentation(rgb)

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(Nuclei_Segmentation, cmap='gray')
plt.axis('off')
plt.show()
